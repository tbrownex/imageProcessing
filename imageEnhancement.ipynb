# %%
import matplotlib.pyplot as plt
import PIL

dataLoc = "/home/tbrownex/"

# %%
def sharpen(img, factor):
    enhancer = ImageEnhance.Sharpness(img)
    return enhancer.enhance(factor)

# %%
def brighten(img, factor):
    enhancer = ImageEnhance.Brightness(img)
    return enhancer.enhance(factor)

# %%
def contrast(img, factor):
    enhancer = ImageEnhance.Contrast(img)
    return enhancer.enhance(factor)

# %%
def getImage():
    name = input("enter image name: ")
    return PIL.Image.open(dataLoc+name)

# %%
def showImage(img):
    plt.imshow(img, interpolation='nearest')
    plt.show()

# %%
img = getImage()
#showImage(img)
# Out:
# enter image name: phuket.jpg

# %%
#newImg = sharpen(img, 2.0)
newImg = brighten(img, 1.5)
newImg = contrast(newImg, 1.5)

# %%
size = 12
f = plt.figure(figsize=(size,size))
f.add_subplot(121)
plt.imshow(img, interpolation='nearest')
f.add_subplot(122)
plt.imshow(newImg, interpolation='nearest')
plt.show()
