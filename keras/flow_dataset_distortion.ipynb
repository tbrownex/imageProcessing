# %%
import PIL
import matplotlib.pyplot as plt
import keras.preprocessing.image as kpi

# %%
parms = {}
parms["directory"] = "/home/tbrownex/data/faces"
parms["batch_size"] = 32
g = kpi.ImageDataGenerator(rotation_range=90)

# %%
train_gen = g.flow_from_directory(
    directory="/home/tbrownex/data/faces",
    target_size=(250,250),
    batch_size=32)
# Out:
# Found 1348 images belonging to 8 classes.

# %%
def showBatch(images, labels):
    imgList = []
    images = images.astype(np.uint8)
    for idx in range(len(images)):
        imgList.append(PIL.Image.fromarray(images[idx]))
    return imgList

# %%
for x in train_gen:
    batchImages, batchLabels = x
    imgList = showBatch(batchImages, batchLabels)
    break

# %%
while True:
    idx = np.random.randint(0,32)
    plt.figure()
    plt.imshow(imgList[idx])
    plt.show()
    input()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/tensorflow/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~/tensorflow/lib/python3.5/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/tensorflow/lib/python3.5/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# ...
